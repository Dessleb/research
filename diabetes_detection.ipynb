# %%
import numpy as np
import pandas as pd

# %%
file_path = 'diabetes_dataset.csv'
df = pd.read_csv(file_path)

# %%
df.shape
# Out:
# (100000, 9)

# %%
df.head()
# Out:
#    gender        age  hypertension  heart_disease smoking_history        bmi  \
# 0  Female  15.845025             0              0           never  21.703385
# 1  Female  49.844857             0              0           never  29.819663
# 2  Female  18.000000             0              0           never  17.770000
# 3    Male  70.000000             0              0           never  27.320000
# 4  Female  57.874248             0              0           never  26.574127
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0     6.430995                  126         1
# 1     6.476729                  145         1
# 2     5.000000                  160         0
# 3     5.801306                  200         1
# 4     6.836522                  130         1

# %%
df.tail()
# Out:
#        gender        age  hypertension  heart_disease smoking_history  \
# 99995    Male  25.000000             0              0         current
# 99996  Female  33.000000             0              0           never
# 99997  Female  71.853063             0              1            ever
# 99998    Male  26.000000             0              0         No Info
# 99999  Female  35.000000             0              0         No Info
#
#              bmi  HbA1c_level  blood_glucose_level  diabetes
# 99995  25.840000     5.700000                  126         0
# 99996  31.143026     7.539537                  130         1
# 99997  26.270733     6.600000                  130         1
# 99998  27.320000     6.500000                   80         0
# 99999  23.100000     6.100000                  100         0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
df.describe()
# Out:
#                  age   hypertension  heart_disease            bmi  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       50.579496       0.074760       0.037220      29.433479
# std        21.513733       0.263005       0.189301       7.348357
# min         0.080000       0.000000       0.000000      10.010000
# 25%        36.000000       0.000000       0.000000      25.940000
# 50%        54.081068       0.000000       0.000000      27.320000
# 75%        67.248249       0.000000       0.000000      32.780000
# max        80.000000       1.000000       1.000000      95.220000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        6.142747           163.559850       0.500000
# std         1.214333            57.090289       0.500003
# min         3.500000            80.000000       0.000000
# 25%         5.700000           130.000000       0.000000
# 50%         6.131714           155.000000       0.500000
# 75%         6.600000           200.000000       1.000000
# max         9.000000           300.000000       1.000000

# %%
df = pd.get_dummies(df,columns=['gender','smoking_history'],drop_first=True)

# %%
df.head()
# Out:
#          age  hypertension  heart_disease        bmi  HbA1c_level  \
# 0  15.845025             0              0  21.703385     6.430995
# 1  49.844857             0              0  29.819663     6.476729
# 2  18.000000             0              0  17.770000     5.000000
# 3  70.000000             0              0  27.320000     5.801306
# 4  57.874248             0              0  26.574127     6.836522
#
#    blood_glucose_level  diabetes  gender_Male  gender_Other  \
# 0                  126         1        False         False
# 1                  145         1        False         False
# 2                  160         0        False         False
# 3                  200         1         True         False
# 4                  130         1        False         False
#
#    smoking_history_current  smoking_history_ever  smoking_history_former  \
# 0                    False                 False                   False
# 1                    False                 False                   False
# 2                    False                 False                   False
# 3                    False                 False                   False
# 4                    False                 False                   False
#
#    smoking_history_never  smoking_history_not current
# 0                   True                        False
# 1                   True                        False
# 2                   True                        False
# 3                   True                        False
# 4                   True                        False

# %%
df.isnull().sum()
# Out:
# age                            0
# hypertension                   0
# heart_disease                  0
# bmi                            0
# HbA1c_level                    0
# blood_glucose_level            0
# diabetes                       0
# gender_Male                    0
# gender_Other                   0
# smoking_history_current        0
# smoking_history_ever           0
# smoking_history_former         0
# smoking_history_never          0
# smoking_history_not current    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# age                            0
# hypertension                   0
# heart_disease                  0
# bmi                            0
# HbA1c_level                    0
# blood_glucose_level            0
# diabetes                       0
# gender_Male                    0
# gender_Other                   0
# smoking_history_current        0
# smoking_history_ever           0
# smoking_history_former         0
# smoking_history_never          0
# smoking_history_not current    0
# dtype: int64

# %%
x=df.drop('diabetes',axis=1)
y = df['diabetes']

# %%
x.head()
# Out:
#          age  hypertension  heart_disease        bmi  HbA1c_level  \
# 0  15.845025             0              0  21.703385     6.430995
# 1  49.844857             0              0  29.819663     6.476729
# 2  18.000000             0              0  17.770000     5.000000
# 3  70.000000             0              0  27.320000     5.801306
# 4  57.874248             0              0  26.574127     6.836522
#
#    blood_glucose_level  gender_Male  gender_Other  smoking_history_current  \
# 0                  126        False         False                    False
# 1                  145        False         False                    False
# 2                  160        False         False                    False
# 3                  200         True         False                    False
# 4                  130        False         False                    False
#
#    smoking_history_ever  smoking_history_former  smoking_history_never  \
# 0                 False                   False                   True
# 1                 False                   False                   True
# 2                 False                   False                   True
# 3                 False                   False                   True
# 4                 False                   False                   True
#
#    smoking_history_not current
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    1
# Name: diabetes, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

# %%
df.describe()
# Out:
#                  age   hypertension  heart_disease            bmi  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       50.579496       0.074760       0.037220      29.433479
# std        21.513733       0.263005       0.189301       7.348357
# min         0.080000       0.000000       0.000000      10.010000
# 25%        36.000000       0.000000       0.000000      25.940000
# 50%        54.081068       0.000000       0.000000      27.320000
# 75%        67.248249       0.000000       0.000000      32.780000
# max        80.000000       1.000000       1.000000      95.220000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        6.142747           163.559850       0.500000
# std         1.214333            57.090289       0.500003
# min         3.500000            80.000000       0.000000
# 25%         5.700000           130.000000       0.000000
# 50%         6.131714           155.000000       0.500000
# 75%         6.600000           200.000000       1.000000
# max         9.000000           300.000000       1.000000

# %%
df['diabetes'].mean()
# Out:
# np.float64(0.5)

# %% [markdown]
# feature scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
cols_to_scale = ['age','bmi','HbA1c_level','blood_glucose_level']
scaler = StandardScaler()

# %%
X_train.loc[:,cols_to_scale] = scaler.fit_transform(X_train[cols_to_scale])
X_test.loc[:,cols_to_scale] = scaler.transform(X_test[cols_to_scale])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6824\2010491779.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.58527799 -0.58527799 -0.07771282 ... -0.41025552 -0.09521507
#  -1.46039035]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_train.loc[:,cols_to_scale] = scaler.fit_transform(X_train[cols_to_scale])
# C:\Users\USER\AppData\Local\Temp\ipykernel_6824\2010491779.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.32274428 -1.37287911 -1.37287911 ...  2.04005908 -0.58527799
#  -0.58527799]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_test.loc[:,cols_to_scale] = scaler.transform(X_test[cols_to_scale])

# %% [markdown]
# class balancing (SMOTE)

# %%
from imblearn.over_sampling import SMOTE

# %%
print(f'Diabetes cases BEFORE SMOTE: {y_train.value_counts()}')
# Out:
# Diabetes cases BEFORE SMOTE: diabetes
# 0    40000
# 1    40000
# Name: count, dtype: int64

# %%
smote = SMOTE(sampling_strategy='minority',random_state=42)

# %%
X_train_resampled,y_train_resampled = smote.fit_resample(X_train,y_train)

# %%
y_test_resampled.value_counts()
# Out:
# diabetes
# 0    18300
# 1    18300
# Name: count, dtype: int64

# %%
from collections import Counter

# %% [markdown]
# model training

# %%
from sklearn.ensemble import RandomForestClassifier as rfc
from sklearn.svm import SVC
import xgboost as xgb
from sklearn.metrics import classification_report

# %% [markdown]
# Random Forest

# %%
'---Training Random Forest ---'
rf_model = rfc(n_estimators=200,random_state=42,n_jobs=-1)
rf_model.fit(X_train_resampled,y_train_resampled)
rf_pred = rf_model.predict(X_test)
print('∖nRandom Forest Report:')
df_report_rf = (pd.DataFrame(classification_report(y_test,rf_pred,output_dict=True)).transpose()).round(4)
# Out:
# ∖nRandom Forest Report:

# %% [markdown]
# XGBoost

# %%
'---Training XGBoost---'
xgb_model = xgb.XGBClassifier(objective='binary:logistic',n_estimators=100,learning_rate=0.1,random_state=42,use_label_encoder=False,eval_metric='logloss',n_jobs=-1)
xgb_model.fit(X_train_resampled,y_train_resampled)
xgb_pred = xgb_model.predict(X_test)
'---XGB Report---'
df_report_xgb = (pd.DataFrame(classification_report(y_test,xgb_pred,output_dict=True)).transpose()).round(4)
# Out:
# c:\Users\USER\Desktop\project\diabetes\venv\Lib\site-packages\xgboost\training.py:199: UserWarning: [00:19:55] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %% [markdown]
# svm model

# %%
svm_model = SVC(kernel='rbf',random_state=42, probability=True)
svm_model.fit(X_train_resampled,y_train_resampled)
svm_pred=svm_model.predict(X_test)
'---SVM Report---'
df_report_svm = (pd.DataFrame(classification_report(y_test,svm_pred,output_dict=True)).transpose()).round(4)

# %%
# %load_ext autoreload
# %autoreload 2
import evaluation2 as eval
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# RF REPORT

# %%
eval.report(y_test, rf_pred, 'Random Forest')
# Out:
# ------Random Forest model report------------
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97     10000
#            1       0.97      0.97      0.97     10000
#
#     accuracy                           0.97     20000
#    macro avg       0.97      0.97      0.97     20000
# weighted avg       0.97      0.97      0.97     20000

# %%
eval.plot_confusion_matrix(y_test,rf_pred,'Random Forest')

# %%
eval.plot_auc_roc_curve(rf_model,'Random Forest',X_test,y_test)

# %% [markdown]
# SVM REPORT

# %%
eval.report(y_test, svm_pred, 'SVM')
eval.plot_confusion_matrix(y_test,svm_pred,'SVM')
eval.plot_auc_roc_curve(svm_model,'SVM',X_test,y_test)
# Out:
# ------SVM model report------------
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91     10000
#            1       0.89      0.93      0.91     10000
#
#     accuracy                           0.91     20000
#    macro avg       0.91      0.91      0.91     20000
# weighted avg       0.91      0.91      0.91     20000

# %% [markdown]
# XGB REPORT

# %%
eval.report(y_test, svm_pred, 'xgb')
eval.plot_confusion_matrix(y_test,xgb_pred,'xgb')
eval.plot_auc_roc_curve(xgb_model,'xgb',X_test,y_test)
# Out:
# ------xgb model report------------
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91     10000
#            1       0.89      0.93      0.91     10000
#
#     accuracy                           0.91     20000
#    macro avg       0.91      0.91      0.91     20000
# weighted avg       0.91      0.91      0.91     20000
